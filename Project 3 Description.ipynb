# %% [markdown]
# For this project you are given a file that contains some parking ticket violations for NYC.
#
# (It's just a tiny extract!)
#
# If you're wondering where I get these data sets, Kaggle is an **excellent** source of data sets in a whole variety of topics:
# https://www.kaggle.com/
#
# You have to sign up, but it's free.
#
# If you want the full data set, it's available here: https://www.kaggle.com/new-york-city/nyc-parking-tickets/version/2#

# %% [markdown]
# ### Project

# %% [markdown]
# For this sample data set, the file is named:
# ```
# nyc_parking_tickets_extract.csv
# ```

# %% [markdown]
# Your goals are as follows:

# %% [markdown]
# ##### Goal 1
# Create a lazy iterator that will return a named tuple of the data in each row. The data types should be appropriate - i.e. if the column is a date, you should be storing dates in the named tuple, if the field is an integer, then it should be stored as an integer, etc.

# %% [markdown]
# ##### Goal 2
#
# Calculate the number of violations by car make.

# %% [markdown]
# ##### Note:
# Try to use lazy evaluation as much as possible - it may not always be possible though! That's OK, as long as it's kept to a minimum.

# %%
from datetime import datetime
from collections import namedtuple

# Iterator solution
class TicketIter:
  def __init__(self):
    self.file = open('nyc_parking_tickets_extract.csv')
    self.Ticket = namedtuple('Ticket', self.transform_row(next(self.file), self.transform_name))

  def transform_row(self, row, callback=None):
    result = row.strip('\n').split(',')
    if callback is None:
      return result
    return callback(result)

  def transform_name(self, names):
    return [('_').join(name.lower().split()) for name in names]

  def transform_type(self, row):
    def transform_type_helper(item):
      try:
        return int(item)
      except Exception:
        try:
          return datetime.strptime(item, '%m/%d/%Y').date();
        except:
          return item
    return [transform_type_helper(item) for item in row]

  def __iter__(self):
    return self

  def __next__(self):
    try:
      return self.Ticket(*self.transform_row(next(self.file), self.transform_type))
    except StopIteration:
      self.file.close()
      raise StopIteration
# ticket = TicketIter()
# print(next(ticket))


# Generator solution //////////
def gen_ticket():
  def transform_row(row, callback=None):
    result = row.strip('\n').split(',')
    if callback is None:
      return result
    return callback(result)

  def transform_name(names):
    return [('_').join(name.lower().split()) for name in names]
    
  def transform_type(data):
    def transform_type_helper(item):
      try:
        return int(item)
      except Exception:
        try:
          return datetime.strptime(item, '%m/%d/%Y').date()
        except Exception:
          return item
    return [transform_type_helper(item) for item in data]

  with open('nyc_parking_tickets_extract.csv') as f:
    Ticket = namedtuple('Ticket', transform_row(next(f), transform_name))
    while True:
      try:
        result = transform_row(next(f), transform_type)
        yield Ticket(*result)
      except StopIteration:
        return None
# ticket = gen_ticket()
# print(next(ticket))
# Out:
# Ticket(summons_number=4006478550, plate_id='VAD7274', registration_state='VA', plate_type='PAS', issue_date=datetime.date(2016, 10, 5), violation_code=5, vehicle_body_type='4D', vehicle_make='BMW', violation_description='BUS LANE VIOLATION')
# Ticket(summons_number=4006462396, plate_id='22834JK', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 9, 30), violation_code=5, vehicle_body_type='VAN', vehicle_make='CHEVR', violation_description='BUS LANE VIOLATION')
# Ticket(summons_number=4007117810, plate_id='21791MG', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 10), violation_code=5, vehicle_body_type='VAN', vehicle_make='DODGE', violation_description='BUS LANE VIOLATION')
# Ticket(summons_number=4006265037, plate_id='FZX9232', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 23), violation_code=5, vehicle_body_type='SUBN', vehicle_make='FORD', violation_description='BUS LANE VIOLATION')
# Ticket(summons_number=4006535600, plate_id='N203399C', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 10, 19), violation_code=5, vehicle_body_type='SUBN', vehicle_make='FORD', violation_description='BUS LANE VIOLATION')
# Ticket(summons_number=4007156700, plate_id='92163MG', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 13), violation_code=5, vehicle_body_type='VAN', vehicle_make='FRUEH', violation_description='BUS LANE VIOLATION')
# Ticket(summons_number=4006687989, plate_id='MIQ600', registration_state='SC', plate_type='PAS', issue_date=datetime.date(2016, 11, 21), violation_code=5, vehicle_body_type='VN', vehicle_make='HONDA', violation_description='BUS LANE VIOLATION')
# Ticket(summons_number=4006943052, plate_id='2AE3984', registration_state='MD', plate_type='PAS', issue_date=datetime.date(2017, 2, 1), violation_code=5, vehicle_body_type='SW', vehicle_make='LINCO', violation_description='BUS LANE VIOLATION')
# Ticket(summons_number=4007306795, plate_id='HLG4926', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 30), violation_code=5, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='BUS LANE VIOLATION')
# Ticket(summons_number=4007124590, plate_id='T715907C', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2017, 4, 3), violation_code=5, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='BUS LANE VIOLATION')
# Ticket(summons_number=5096061966, plate_id='HRC9475', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 18), violation_code=7, vehicle_body_type='SUBN', vehicle_make='CADIL', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5094070400, plate_id='DYP8042', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 26), violation_code=7, vehicle_body_type='SUBN', vehicle_make='CHEVR', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5094906770, plate_id='G30ESY', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 1, 1), violation_code=7, vehicle_body_type='WAGO', vehicle_make='CHRYS', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5093319363, plate_id='GGT8868', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 6), violation_code=7, vehicle_body_type='SUBN', vehicle_make='CHRYS', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5092638849, plate_id='107DDD', registration_state='NY', plate_type='SPO', issue_date=datetime.date(2016, 7, 20), violation_code=7, vehicle_body_type='SUBN', vehicle_make='DODGE', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5093455337, plate_id='ENQT55', registration_state='FL', plate_type='PAS', issue_date=datetime.date(2016, 9, 12), violation_code=7, vehicle_body_type='VN', vehicle_make='DODGE', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5094961366, plate_id='GSU4156', registration_state='OH', plate_type='PAS', issue_date=datetime.date(2017, 1, 7), violation_code=7, vehicle_body_type='4S', vehicle_make='DODGE', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5092906534, plate_id='V84FXV', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 8, 7), violation_code=7, vehicle_body_type='WAGO', vehicle_make='FIR', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5093620865, plate_id='AD80228', registration_state='AZ', plate_type='PAS', issue_date=datetime.date(2016, 9, 24), violation_code=7, vehicle_body_type='TK', vehicle_make='FORD', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5092733548, plate_id='EVX4041', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 26), violation_code=7, vehicle_body_type='SUBN', vehicle_make='FORD', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5095995530, plate_id='EMK5934', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 13), violation_code=7, vehicle_body_type='VAN', vehicle_make='GMC', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5092750364, plate_id='DPH8955', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 27), violation_code=7, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5094658001, plate_id='GCF1897', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 10), violation_code=7, vehicle_body_type='4DSD', vehicle_make='HONDA', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5092833786, plate_id='HCS9434', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 3), violation_code=7, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5096484040, plate_id='HHS1641', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 17), violation_code=7, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5095797586, plate_id='KHE1889', registration_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 3, 28), violation_code=7, vehicle_body_type='SDN', vehicle_make='HONDA', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5095799807, plate_id='VES2440', registration_state='VA', plate_type='PAS', issue_date=datetime.date(2017, 3, 29), violation_code=7, vehicle_body_type='VAN', vehicle_make='HONDA', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5093533919, plate_id='CYU4598', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 16), violation_code=7, vehicle_body_type='SUBN', vehicle_make='HYUND', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5093399735, plate_id='DZGT24', registration_state='FL', plate_type='PAS', issue_date=datetime.date(2016, 9, 4), violation_code=7, vehicle_body_type='UT', vehicle_make='HYUND', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5094058873, plate_id='GRN3101', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 29), violation_code=7, vehicle_body_type='4DSD', vehicle_make='HYUND', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5094770986, plate_id='T668962C', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 12, 19), violation_code=7, vehicle_body_type='4DSD', vehicle_make='HYUND', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5093895611, plate_id='GVZ1407', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 14), violation_code=7, vehicle_body_type='4DSD', vehicle_make='JAGUA', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5094185792, plate_id='AGM9013', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 4), violation_code=7, vehicle_body_type='SUBN', vehicle_make='JEEP', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5092708219, plate_id='F47DZF', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 7, 24), violation_code=7, vehicle_body_type='4 DR', vehicle_make='JEEP', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5094759954, plate_id='GLB8157', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 19), violation_code=7, vehicle_body_type='SUBN', vehicle_make='JEEP', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5093891046, plate_id='FJS4033', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 14), violation_code=7, vehicle_body_type='4DSD', vehicle_make='LEXUS', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5093527853, plate_id='GYM9809', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 21), violation_code=7, vehicle_body_type='4DSD', vehicle_make='LEXUS', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5096683886, plate_id='HCS4873', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 18), violation_code=7, vehicle_body_type='4DSD', vehicle_make='LEXUS', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5096917368, plate_id='FZD8593', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 13), violation_code=7, vehicle_body_type='SUBN', vehicle_make='ME/BE', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5094893737, plate_id='GER1584', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 31), violation_code=7, vehicle_body_type='4DSD', vehicle_make='ME/BE', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5096249300, plate_id='HEM8411', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 1), violation_code=7, vehicle_body_type='4DSD', vehicle_make='ME/BE', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5096958772, plate_id='165TRX', registration_state='CT', plate_type='PAS', issue_date=datetime.date(2017, 6, 16), violation_code=7, vehicle_body_type='4W', vehicle_make='MERCU', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5093703217, plate_id='HFG4313', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 30), violation_code=7, vehicle_body_type='4DSD', vehicle_make='MITSU', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5094670736, plate_id='AXU4790', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 11), violation_code=7, vehicle_body_type='4DSD', vehicle_make='NISSA', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5094094166, plate_id='CZM4111', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 28), violation_code=7, vehicle_body_type='4DSD', vehicle_make='TOYOT', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5096723768, plate_id='EDN2797', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 2), violation_code=7, vehicle_body_type='4DSD', vehicle_make='TOYOT', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5093209120, plate_id='FZT5005', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 28), violation_code=7, vehicle_body_type='4DSD', vehicle_make='TOYOT', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5092469481, plate_id='GZH7067', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 10), violation_code=7, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5092451658, plate_id='GZH7067', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 8), violation_code=7, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=5095356545, plate_id='GZM8254', registration_state='NY', plate_type='OMS', issue_date=datetime.date(2017, 2, 18), violation_code=7, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='FAILURE TO STOP AT RED LIGHT')
# Ticket(summons_number=8410006650, plate_id='D53AUUN', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 10, 21), violation_code=9, vehicle_body_type='4DSD', vehicle_make='LEXUS', violation_description='09-Blocking the Box')
# Ticket(summons_number=8534116519, plate_id='CES6482', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 12), violation_code=9, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='09-Blocking the Box')
# Ticket(summons_number=8485674984, plate_id='T713160C', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2017, 6, 13), violation_code=9, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='09-Blocking the Box')
# Ticket(summons_number=8556557405, plate_id='59622JW', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 9), violation_code=10, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='10-No Stopping')
# Ticket(summons_number=8071038416, plate_id='AM479F', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 7, 7), violation_code=10, vehicle_body_type='DELV', vehicle_make='FRUEH', violation_description='10-No Stopping')
# Ticket(summons_number=8483087236, plate_id='76822MH', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 5, 19), violation_code=10, vehicle_body_type='DELV', vehicle_make='HIN', violation_description='10-No Stopping')
# Ticket(summons_number=8481125088, plate_id='55179ME', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 10), violation_code=10, vehicle_body_type='DELV', vehicle_make='NS/OT', violation_description='10-No Stopping')
# Ticket(summons_number=8506822300, plate_id='55106MB', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 5, 31), violation_code=10, vehicle_body_type='VAN', vehicle_make='WORKH', violation_description='10-No Stopping')
# Ticket(summons_number=8482331425, plate_id='86609MB', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 18), violation_code=13, vehicle_body_type='VAN', vehicle_make='CHEVR', violation_description='13-No Stand (taxi stand)')
# Ticket(summons_number=8028246722, plate_id='T703619C', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 9, 15), violation_code=13, vehicle_body_type='SUBN', vehicle_make='CHEVR', violation_description='13-No Stand (taxi stand)')
# Ticket(summons_number=8378547530, plate_id='FWZ8815', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 11), violation_code=14, vehicle_body_type='2DSD', vehicle_make='ACURA', violation_description='14-No Standing')
# Ticket(summons_number=8489750210, plate_id='6DQT356', registration_state='CA', plate_type='PAS', issue_date=datetime.date(2016, 11, 28), violation_code=14, vehicle_body_type='4DSD', vehicle_make='AUDI', violation_description='14-No Standing')
# Ticket(summons_number=1410726095, plate_id='DEP4792', registration_state='NC', plate_type='PAS', issue_date=datetime.date(2016, 7, 15), violation_code=14, vehicle_body_type='', vehicle_make='BMW', violation_description='')
# Ticket(summons_number=8421031235, plate_id='GGA4266', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 18), violation_code=14, vehicle_body_type='4DSD', vehicle_make='BMW', violation_description='14-No Standing')
# Ticket(summons_number=7730553259, plate_id='DLZ8901', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 26), violation_code=14, vehicle_body_type='SUBN', vehicle_make='CHEVR', violation_description='14-No Standing')
# Ticket(summons_number=8498520046, plate_id='HKF6916', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 27), violation_code=14, vehicle_body_type='SUBN', vehicle_make='CHEVR', violation_description='14-No Standing')
# Ticket(summons_number=8537807813, plate_id='HNF6718', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 21), violation_code=14, vehicle_body_type='SUBN', vehicle_make='CHEVR', violation_description='14-No Standing')
# Ticket(summons_number=8083571465, plate_id='KCG9559', registration_state='PA', plate_type='PAS', issue_date=datetime.date(2016, 12, 22), violation_code=14, vehicle_body_type='SUBN', vehicle_make='CHEVR', violation_description='14-No Standing')
# Ticket(summons_number=7536689184, plate_id='ZCL5723', registration_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 1, 26), violation_code=14, vehicle_body_type='VAN', vehicle_make='CHEVR', violation_description='14-No Standing')
# Ticket(summons_number=8480505680, plate_id='HCT2134', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 18), violation_code=14, vehicle_body_type='SUBN', vehicle_make='CHRYS', violation_description='14-No Standing')
# Ticket(summons_number=8481973580, plate_id='28693MH', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 13), violation_code=14, vehicle_body_type='VAN', vehicle_make='DODGE', violation_description='14-No Standing')
# Ticket(summons_number=8460500214, plate_id='30408MC', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 8, 4), violation_code=14, vehicle_body_type='PICK', vehicle_make='DODGE', violation_description='14-No Standing')
# Ticket(summons_number=8482817036, plate_id='50501JT', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 11), violation_code=14, vehicle_body_type='VAN', vehicle_make='DODGE', violation_description='14-No Standing')
# Ticket(summons_number=8117027999, plate_id='83317ME', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 9, 27), violation_code=14, vehicle_body_type='VAN', vehicle_make='DODGE', violation_description='14-No Standing')
# Ticket(summons_number=8488121532, plate_id='FLX2674', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 5), violation_code=14, vehicle_body_type='2DSD', vehicle_make='DODGE', violation_description='14-No Standing')
# Ticket(summons_number=8543952980, plate_id='FSZ8671', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 21), violation_code=14, vehicle_body_type='SUBN', vehicle_make='DODGE', violation_description='14-No Standing')
# Ticket(summons_number=8501806912, plate_id='KGP1166', registration_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 6, 4), violation_code=14, vehicle_body_type='VAN', vehicle_make='DODGE', violation_description='14-No Standing')
# Ticket(summons_number=8107542976, plate_id='11AH74', registration_state='MA', plate_type='PAS', issue_date=datetime.date(2017, 1, 29), violation_code=14, vehicle_body_type='4DSD', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=8564650320, plate_id='29222MK', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 5, 5), violation_code=14, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=8010367576, plate_id='30661MA', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 12, 22), violation_code=14, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=8505159536, plate_id='41795JX', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 3, 9), violation_code=14, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=7813887440, plate_id='44267JZ', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 8, 12), violation_code=14, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=8440509546, plate_id='49317JX', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 10, 29), violation_code=14, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=1408575656, plate_id='6XWZ969', registration_state='CA', plate_type='PAS', issue_date=datetime.date(2016, 7, 6), violation_code=14, vehicle_body_type='SDN', vehicle_make='FORD', violation_description='')
# Ticket(summons_number=8516853275, plate_id='72100MH', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 12), violation_code=14, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=7059924103, plate_id='91878MB', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 10, 12), violation_code=14, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=8170085561, plate_id='ENM3708', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 10), violation_code=14, vehicle_body_type='SUBN', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=8527511113, plate_id='F70GEP', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 5, 1), violation_code=14, vehicle_body_type='SUBN', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=8511453696, plate_id='FSY6987', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 13), violation_code=14, vehicle_body_type='SUBN', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=1413745933, plate_id='HCC2829', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 22), violation_code=14, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='')
# Ticket(summons_number=8484882226, plate_id='S25DSK', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 6, 8), violation_code=14, vehicle_body_type='PICK', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=8524054499, plate_id='ZRK24R', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 3, 18), violation_code=14, vehicle_body_type='SUBN', vehicle_make='FORD', violation_description='14-No Standing')
# Ticket(summons_number=1423945281, plate_id=2240653, registration_state='IN', plate_type='PAS', issue_date=datetime.date(2017, 5, 13), violation_code=14, vehicle_body_type='', vehicle_make='FRUEH', violation_description='')
# Ticket(summons_number=8577650820, plate_id='10632JU', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 20), violation_code=14, vehicle_body_type='UTIL', vehicle_make='FRUEH', violation_description='14-No Standing')
# Ticket(summons_number=7056662882, plate_id='83038ME', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 9, 21), violation_code=14, vehicle_body_type='VAN', vehicle_make='FRUEH', violation_description='14-No Standing')
# Ticket(summons_number=8324025510, plate_id='83146ME', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 10, 27), violation_code=14, vehicle_body_type='VAN', vehicle_make='FRUEH', violation_description='14-No Standing')
# Ticket(summons_number=8286541110, plate_id='85846MD', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 10, 25), violation_code=14, vehicle_body_type='VAN', vehicle_make='FRUEH', violation_description='14-No Standing')
# Ticket(summons_number=8270548250, plate_id='91028MJ', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 12, 13), violation_code=14, vehicle_body_type='DELV', vehicle_make='FRUEH', violation_description='14-No Standing')
# Ticket(summons_number=8480520395, plate_id='99886MC', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 19), violation_code=14, vehicle_body_type='VAN', vehicle_make='FRUEH', violation_description='14-No Standing')
# Ticket(summons_number=8496410791, plate_id='AP338E', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 5, 17), violation_code=14, vehicle_body_type='TRAC', vehicle_make='FRUEH', violation_description='14-No Standing')
# Ticket(summons_number=8530950458, plate_id='HAY5880', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 8), violation_code=14, vehicle_body_type='SUBN', vehicle_make='GMC', violation_description='14-No Standing')
# Ticket(summons_number=8552003569, plate_id='XJ275S', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 4, 25), violation_code=14, vehicle_body_type='PICK', vehicle_make='GMC', violation_description='14-No Standing')
# Ticket(summons_number=8536010903, plate_id='25472MG', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 16), violation_code=14, vehicle_body_type='REFG', vehicle_make='HIN', violation_description='14-No Standing')
# Ticket(summons_number=8508953549, plate_id='XDLS80', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 2, 1), violation_code=14, vehicle_body_type='DELV', vehicle_make='HIN', violation_description='14-No Standing')
# Ticket(summons_number=7191990831, plate_id='AA00234', registration_state='CT', plate_type='PAS', issue_date=datetime.date(2016, 7, 2), violation_code=14, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='14-No Standing')
# Ticket(summons_number=8519503676, plate_id='FCX7311', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 20), violation_code=14, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='14-No Standing')
# Ticket(summons_number=1418739704, plate_id='GJK5307', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 9), violation_code=14, vehicle_body_type='SDN', vehicle_make='HONDA', violation_description='')
# Ticket(summons_number=7994359840, plate_id='GNG1097', registration_state='TX', plate_type='PAS', issue_date=datetime.date(2016, 7, 15), violation_code=14, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='14-No Standing')
# Ticket(summons_number=1414856374, plate_id='HLE9929', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 13), violation_code=14, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='')
# Ticket(summons_number=8474909971, plate_id='S938464', registration_state='IA', plate_type='PAS', issue_date=datetime.date(2017, 1, 9), violation_code=14, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='14-No Standing')
# Ticket(summons_number=1416903379, plate_id='CRM6911', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 16), violation_code=14, vehicle_body_type='SDN', vehicle_make='HYUND', violation_description='')
# Ticket(summons_number=8340512559, plate_id='CZB9676', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 23), violation_code=14, vehicle_body_type='2DSD', vehicle_make='HYUND', violation_description='14-No Standing')
# Ticket(summons_number=8497566683, plate_id='17596JE', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 16), violation_code=14, vehicle_body_type='DELV', vehicle_make='INTER', violation_description='14-No Standing')
# Ticket(summons_number=8517821075, plate_id='32295MA', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 27), violation_code=14, vehicle_body_type='DELV', vehicle_make='INTER', violation_description='14-No Standing')
# Ticket(summons_number=1418035762, plate_id='62935JM', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 24), violation_code=14, vehicle_body_type='DELV', vehicle_make='INTER', violation_description='')
# Ticket(summons_number=8482055392, plate_id='92638JU', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 25), violation_code=14, vehicle_body_type='VAN', vehicle_make='INTER', violation_description='14-No Standing')
# Ticket(summons_number=8506706490, plate_id='AP166T', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 2, 20), violation_code=14, vehicle_body_type='DELV', vehicle_make='INTER', violation_description='14-No Standing')
# Ticket(summons_number=8473761297, plate_id='33049MJ', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 2, 1), violation_code=14, vehicle_body_type='DELV', vehicle_make='ISUZU', violation_description='14-No Standing')
# Ticket(summons_number=8484877693, plate_id='XBYG52', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 5, 12), violation_code=14, vehicle_body_type='VAN', vehicle_make='ISUZU', violation_description='14-No Standing')
# Ticket(summons_number=8152046917, plate_id='VFW9441', registration_state='VA', plate_type='PAS', issue_date=datetime.date(2016, 8, 14), violation_code=14, vehicle_body_type='SUBN', vehicle_make='JEEP', violation_description='14-No Standing')
# Ticket(summons_number=8503265503, plate_id='23800TC', registration_state='NY', plate_type='TRC', issue_date=datetime.date(2017, 3, 28), violation_code=14, vehicle_body_type='TRAC', vehicle_make='KENWO', violation_description='14-No Standing')
# Ticket(summons_number=8489721312, plate_id='49734MA', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 4), violation_code=14, vehicle_body_type='DELV', vehicle_make='KENWO', violation_description='14-No Standing')
# Ticket(summons_number=8464532088, plate_id='HJR5750', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 3), violation_code=14, vehicle_body_type='SUBN', vehicle_make='KIA', violation_description='14-No Standing')
# Ticket(summons_number=8488825948, plate_id='HAU1278', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 31), violation_code=14, vehicle_body_type='SUBN', vehicle_make='LEXUS', violation_description='14-No Standing')
# Ticket(summons_number=8559362496, plate_id='HLW7798', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 13), violation_code=14, vehicle_body_type='4DSD', vehicle_make='LEXUS', violation_description='14-No Standing')
# Ticket(summons_number=8478353860, plate_id='VUE95C', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 12, 6), violation_code=14, vehicle_body_type='4DSD', vehicle_make='LEXUS', violation_description='14-No Standing')
# Ticket(summons_number=8518911631, plate_id='ZD53LE', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 5, 17), violation_code=14, vehicle_body_type='SUBN', vehicle_make='LEXUS', violation_description='14-No Standing')
# Ticket(summons_number=1416091415, plate_id='75213MH', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 11, 28), violation_code=14, vehicle_body_type='VAN', vehicle_make='ME/BE', violation_description='')
# Ticket(summons_number=8482374059, plate_id='F96FBF', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 4, 23), violation_code=14, vehicle_body_type='4DSD', vehicle_make='ME/BE', violation_description='14-No Standing')
# Ticket(summons_number=8544960947, plate_id='HMX8950', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 27), violation_code=14, vehicle_body_type='4DSD', vehicle_make='ME/BE', violation_description='14-No Standing')
# Ticket(summons_number=1418609274, plate_id='8P82H', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 12, 21), violation_code=14, vehicle_body_type='TAXI', vehicle_make='NISSA', violation_description='')
# Ticket(summons_number=1417565895, plate_id='HEB8184', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 11), violation_code=14, vehicle_body_type='SDN', vehicle_make='NISSA', violation_description='')
# Ticket(summons_number=8155550278, plate_id='W56GSE', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 10, 22), violation_code=14, vehicle_body_type='4DSD', vehicle_make='NISSA', violation_description='14-No Standing')
# Ticket(summons_number=7433187960, plate_id=2330830, registration_state='ME', plate_type='PAS', issue_date=datetime.date(2017, 3, 6), violation_code=14, vehicle_body_type='TRLR', vehicle_make='NS/OT', violation_description='14-No Standing')
# Ticket(summons_number=7645052715, plate_id='FRZ3573', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 7), violation_code=14, vehicle_body_type='SUBN', vehicle_make='NS/OT', violation_description='14-No Standing')
# Ticket(summons_number=7922559173, plate_id='XCYU94', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 10, 24), violation_code=14, vehicle_body_type='VAN', vehicle_make='NS/OT', violation_description='14-No Standing')
# Ticket(summons_number=7767415582, plate_id='XW915N', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 3, 29), violation_code=14, vehicle_body_type='DELV', vehicle_make='NS/OT', violation_description='14-No Standing')
# Ticket(summons_number=8524350581, plate_id='HGR5953', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 27), violation_code=14, vehicle_body_type='4DSD', vehicle_make='OLDSM', violation_description='14-No Standing')
# Ticket(summons_number=7499844705, plate_id='GGT7948', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 22), violation_code=14, vehicle_body_type='SUBN', vehicle_make='SUBAR', violation_description='14-No Standing')
# Ticket(summons_number=7150327266, plate_id='HWE6388', registration_state='PA', plate_type='PAS', issue_date=datetime.date(2016, 8, 5), violation_code=14, vehicle_body_type='SUBN', vehicle_make='SUBAR', violation_description='14-No Standing')
# Ticket(summons_number=8537603818, plate_id='ASG8770', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 26), violation_code=14, vehicle_body_type='4DSD', vehicle_make='TOYOT', violation_description='14-No Standing')
# Ticket(summons_number=8210533952, plate_id='GST8679', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 21), violation_code=14, vehicle_body_type='2DSD', vehicle_make='TOYOT', violation_description='14-No Standing')
# Ticket(summons_number=8555462198, plate_id='HKT4222', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 12), violation_code=14, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='14-No Standing')
# Ticket(summons_number=1404838156, plate_id='R57AAE', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 4, 29), violation_code=14, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='')
# Ticket(summons_number=8527806162, plate_id='T659832C', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2017, 6, 4), violation_code=14, vehicle_body_type='4DSD', vehicle_make='TOYOT', violation_description='14-No Standing')
# Ticket(summons_number=8513520615, plate_id='77026MG', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 5, 31), violation_code=14, vehicle_body_type='TRAC', vehicle_make='VOLVO', violation_description='14-No Standing')
# Ticket(summons_number=8251031485, plate_id='HJP5565', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 4), violation_code=16, vehicle_body_type='4DSD', vehicle_make='CHEVR', violation_description='16A-No Std (Com Veh) Non-COM')
# Ticket(summons_number=7813745231, plate_id='GEL1890', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 19), violation_code=16, vehicle_body_type='SUBN', vehicle_make='CHRYS', violation_description='16A-No Std (Com Veh) Non-COM')
# Ticket(summons_number=8444534183, plate_id='36598MH', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 11, 23), violation_code=16, vehicle_body_type='VAN', vehicle_make='DODGE', violation_description='16-No Std (Com Veh) Com Plate')
# Ticket(summons_number=8061037749, plate_id='HFG7121', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 22), violation_code=16, vehicle_body_type='SUBN', vehicle_make='DODGE', violation_description='16A-No Std (Com Veh) Non-COM')
# Ticket(summons_number=8250539527, plate_id='24745ME', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 11, 9), violation_code=16, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='16-No Std (Com Veh) Com Plate')
# Ticket(summons_number=8308520170, plate_id='49033ME', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 7, 14), violation_code=16, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='16-No Std (Com Veh) Com Plate')
# Ticket(summons_number=8504915323, plate_id='57011ME', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 4, 6), violation_code=16, vehicle_body_type='SUBN', vehicle_make='FORD', violation_description='16-No Std (Com Veh) Com Plate')
# Ticket(summons_number=8339536023, plate_id='XCEG93', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 9, 15), violation_code=16, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='16-No Std (Com Veh) Com Plate')
# Ticket(summons_number=8566405183, plate_id='GJD5585', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 1), violation_code=16, vehicle_body_type='4DSD', vehicle_make='ME/BE', violation_description='16A-No Std (Com Veh) Non-COM')
# Ticket(summons_number=7051225662, plate_id='N61GZN', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 11, 25), violation_code=16, vehicle_body_type='SUBN', vehicle_make='SATUR', violation_description='16A-No Std (Com Veh) Non-COM')
# Ticket(summons_number=8149510126, plate_id='GTP8988', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 10), violation_code=16, vehicle_body_type='2DSD', vehicle_make='SMART', violation_description='16A-No Std (Com Veh) Non-COM')
# Ticket(summons_number=7052028463, plate_id='HGM9782', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 30), violation_code=16, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='16A-No Std (Com Veh) Non-COM')
# Ticket(summons_number=8474913706, plate_id='T674455C', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2017, 2, 8), violation_code=16, vehicle_body_type='4DSD', vehicle_make='TOYOT', violation_description='16A-No Std (Com Veh) Non-COM')
# Ticket(summons_number=8506607206, plate_id='18752MH', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 3, 16), violation_code=17, vehicle_body_type='VAN', vehicle_make='CHEVR', violation_description='17-No Stand (exc auth veh)')
# Ticket(summons_number=8438519763, plate_id='89882JV', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 10, 13), violation_code=17, vehicle_body_type='VAN', vehicle_make='GMC', violation_description='17-No Stand (exc auth veh)')
# Ticket(summons_number=8551111954, plate_id='GCE9214', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 25), violation_code=17, vehicle_body_type='4DSD', vehicle_make='HONDA', violation_description='17-No Stand (exc auth veh)')
# Ticket(summons_number=8516654059, plate_id='AP169V', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 2, 22), violation_code=18, vehicle_body_type='DELV', vehicle_make='INTER', violation_description='18-No Stand (bus lane)')
# Ticket(summons_number=1368119141, plate_id='BMLV150', registration_state='ON', plate_type='PAS', issue_date=datetime.date(2016, 7, 16), violation_code=19, vehicle_body_type='SUBN', vehicle_make='CHEVR', violation_description='')
# Ticket(summons_number=8528274184, plate_id='EKF9820', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 1), violation_code=19, vehicle_body_type='SUBN', vehicle_make='CHEVR', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=8522350073, plate_id='83290MD', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 2, 24), violation_code=19, vehicle_body_type='SUBN', vehicle_make='DODGE', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=8070097437, plate_id='T62GJP', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 9, 18), violation_code=19, vehicle_body_type='PICK', vehicle_make='DODGE', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=8509409523, plate_id='35050JU', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 2, 24), violation_code=19, vehicle_body_type='PICK', vehicle_make='FORD', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=1413553552, plate_id='41126BB', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 7, 28), violation_code=19, vehicle_body_type='VAN', vehicle_make='FORD', violation_description='')
# Ticket(summons_number=8514220482, plate_id=2588073, registration_state='IN', plate_type='PAS', issue_date=datetime.date(2017, 5, 29), violation_code=19, vehicle_body_type='DELV', vehicle_make='FRUEH', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=8485652319, plate_id='0480PRA', registration_state='MN', plate_type='PAS', issue_date=datetime.date(2017, 1, 26), violation_code=19, vehicle_body_type='DELV', vehicle_make='FRUEH', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=7014671406, plate_id='B0951V', registration_state='FL', plate_type='PAS', issue_date=datetime.date(2016, 9, 7), violation_code=19, vehicle_body_type='DELV', vehicle_make='FRUEH', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=1422732710, plate_id='GMK4592', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 19), violation_code=19, vehicle_body_type='SDN', vehicle_make='HONDA', violation_description='')
# Ticket(summons_number=7249114220, plate_id='GPP7413', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 8), violation_code=19, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=7499990163, plate_id='HKT3209', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 13), violation_code=19, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=8491667738, plate_id='JPC4516', registration_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 3, 1), violation_code=19, vehicle_body_type='4DSD', vehicle_make='INFIN', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=8302046280, plate_id='63444JM', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 26), violation_code=19, vehicle_body_type='VAN', vehicle_make='INTER', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=8009901763, plate_id='13657MD', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 9, 27), violation_code=19, vehicle_body_type='DELV', vehicle_make='KENWO', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=1424024420, plate_id='HPD1970', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 10), violation_code=19, vehicle_body_type='SDN', vehicle_make='KIA', violation_description='')
# Ticket(summons_number=8511718990, plate_id='50104MH', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 6, 9), violation_code=19, vehicle_body_type='VAN', vehicle_make='ME/BE', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=1415429522, plate_id='17236MH', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 3, 3), violation_code=19, vehicle_body_type='SUBN', vehicle_make='MITSU', violation_description='')
# Ticket(summons_number=8476355312, plate_id='47829MD', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 2, 14), violation_code=19, vehicle_body_type='DELV', vehicle_make='PETER', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=1406918726, plate_id='5M39B', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 7, 13), violation_code=19, vehicle_body_type='TAXI', vehicle_make='TOYOT', violation_description='')
# Ticket(summons_number=7241990262, plate_id='DVA1919', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 16), violation_code=19, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=8330511935, plate_id='HBY7509', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 30), violation_code=19, vehicle_body_type='4DSD', vehicle_make='TOYOT', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=1423536058, plate_id='HCS2336', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 27), violation_code=19, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='')
# Ticket(summons_number=8519016595, plate_id='QU655', registration_state='RI', plate_type='PAS', issue_date=datetime.date(2017, 6, 12), violation_code=19, vehicle_body_type='4DSD', vehicle_make='TOYOT', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=8530522310, plate_id='T640396C', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2017, 5, 27), violation_code=19, vehicle_body_type='4DSD', vehicle_make='TOYOT', violation_description='19-No Stand (bus stop)')
# Ticket(summons_number=1413358512, plate_id='54295PC', registration_state='NY', plate_type='APP', issue_date=datetime.date(2016, 8, 9), violation_code=19, vehicle_body_type='BUS', vehicle_make='', violation_description='')
# Ticket(summons_number=8269048434, plate_id='CDPE57', registration_state='FL', plate_type='PAS', issue_date=datetime.date(2016, 8, 21), violation_code=20, vehicle_body_type='4DSD', vehicle_make='ACURA', violation_description='20A-No Parking (Non-COM)')
# Ticket(summons_number=7036998684, plate_id='VML8110', registration_state='VA', plate_type='PAS', issue_date=datetime.date(2017, 2, 21), violation_code=20, vehicle_body_type='4DSD', vehicle_make='BMW', violation_description='20A-No Parking (Non-COM)')
# Ticket(summons_number=8515215408, plate_id='HFB1731', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 14), violation_code=20, vehicle_body_type='SUBN', vehicle_make='CADIL', violation_description='20A-No Parking (Non-COM)')
# Ticket(summons_number=8470607042, plate_id='MYSUMMER', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 7, 27), violation_code=20, vehicle_body_type='SUBN', vehicle_make='CADIL', violation_description='20A-No Parking (Non-COM)')
# Ticket(summons_number=1371960501, plate_id='FEP2455', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 18), violation_code=20, vehicle_body_type='SUBN', vehicle_make='CHEVR', violation_description='')
# Ticket(summons_number=8550963045, plate_id='GSU8031', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 20), violation_code=20, vehicle_body_type='4DSD', vehicle_make='CHEVR', violation_description='20A-No Parking (Non-COM)')
# ...
# Ticket(summons_number=8467031128, plate_id='R9D509', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 24), violation_code=71, vehicle_body_type='SUBN', vehicle_make='HYUND', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8378044166, plate_id='HJV2326', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 18), violation_code=71, vehicle_body_type='4DSD', vehicle_make='INFIN', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8535421774, plate_id='EGZ5296', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 21), violation_code=71, vehicle_body_type='SUBN', vehicle_make='JEEP', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8263642668, plate_id='HEA6308', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 16), violation_code=71, vehicle_body_type='SUBN', vehicle_make='JEEP', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=7067047705, plate_id='HFF1432', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 23), violation_code=71, vehicle_body_type='SUBN', vehicle_make='JEEP', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8168032202, plate_id='GZN5776', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 3), violation_code=71, vehicle_body_type='4DSD', vehicle_make='LEXUS', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8507861787, plate_id='HMY3697', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 10), violation_code=71, vehicle_body_type='SUBN', vehicle_make='LEXUS', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8297047957, plate_id='GUV7315', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 12, 3), violation_code=71, vehicle_body_type='4DSD', vehicle_make='LINCO', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8472853342, plate_id='HJN6543', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 4), violation_code=71, vehicle_body_type='2DSD', vehicle_make='LINCO', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8524860388, plate_id='HGR2303', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 10), violation_code=71, vehicle_body_type='CONV', vehicle_make='ME/BE', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8561753377, plate_id='GWY8527', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 26), violation_code=71, vehicle_body_type='SUBN', vehicle_make='MERCU', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8544876754, plate_id='GBE4270', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 24), violation_code=71, vehicle_body_type='4DSD', vehicle_make='NISSA', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=7803960030, plate_id='HBU4265', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 7), violation_code=71, vehicle_body_type='4DSD', vehicle_make='NISSA', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=7492597289, plate_id='HDF5609', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 19), violation_code=71, vehicle_body_type='4DSD', vehicle_make='NISSA', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8400523477, plate_id='HKT1200', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 28), violation_code=71, vehicle_body_type='4DSD', vehicle_make='NISSA', violation_description='71-Insp. Sticker Missing (NYS')
# Ticket(summons_number=7646792536, plate_id='T686872C', registration_state='NY', plate_type='OMT', issue_date=datetime.date(2016, 9, 14), violation_code=71, vehicle_body_type='4DSD', vehicle_make='NISSA', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8208026335, plate_id='DHW7141', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 5), violation_code=71, vehicle_body_type='2DSD', vehicle_make='NS/OT', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=7959796476, plate_id='GPY8489', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 6), violation_code=71, vehicle_body_type='SUBN', vehicle_make='ROVER', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8509455028, plate_id='34632BB', registration_state='NY', plate_type='OMR', issue_date=datetime.date(2017, 2, 12), violation_code=71, vehicle_body_type='BUS', vehicle_make='STAR', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8393022400, plate_id='HFP5696', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 11, 16), violation_code=71, vehicle_body_type='SUBN', vehicle_make='SUBAR', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8525217207, plate_id='HGM9849', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 3), violation_code=71, vehicle_body_type='SUBN', vehicle_make='SUBAR', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8562558047, plate_id='CWP4893', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 1), violation_code=71, vehicle_body_type='SUBN', vehicle_make='TOYOT', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8236037095, plate_id='GMR8112', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 17), violation_code=71, vehicle_body_type='2DSD', vehicle_make='TOYOT', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8514463690, plate_id='GMZ9712', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 30), violation_code=71, vehicle_body_type='4DSD', vehicle_make='TOYOT', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=8358550790, plate_id='HDY4158', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 18), violation_code=71, vehicle_body_type='4DSD', vehicle_make='TOYOT', violation_description='71A-Insp Sticker Expired (NYS)')
# Ticket(summons_number=7959486440, plate_id='GYF2052', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 7, 7), violation_code=71, vehicle_body_type='4DSD', vehicle_make='VOLKS', violation_description='71-Insp. Sticker Missing (NYS')
# Ticket(summons_number=8300538318, plate_id='HFR6545', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 31), violation_code=71, vehicle_body_type='4DSD', vehicle_make='VOLVO', violation_description='71-Insp. Sticker Missing (NYS')
# Ticket(summons_number=8523013120, plate_id='HPN9774', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 6), violation_code=74, vehicle_body_type='4DSD', vehicle_make='CHEVR', violation_description='74-Missing Display Plate')
# Ticket(summons_number=7008336767, plate_id='HWL4734', registration_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 1, 14), violation_code=74, vehicle_body_type='4DSD', vehicle_make='CHEVR', violation_description='74A-Improperly Displayed Plate')
# Ticket(summons_number=8397514636, plate_id='FYW3850', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 10, 22), violation_code=74, vehicle_body_type='SUBN', vehicle_make='FORD', violation_description='74A-Improperly Displayed Plate')
# Ticket(summons_number=8528912840, plate_id='HNY5206', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 21), violation_code=74, vehicle_body_type='SUBN', vehicle_make='GMC', violation_description='74A-Improperly Displayed Plate')
# Ticket(summons_number=8511501113, plate_id='FBP6836', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 2, 16), violation_code=74, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='74-Missing Display Plate')
# Ticket(summons_number=8276551890, plate_id='HJR4081', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 1, 7), violation_code=74, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='74A-Improperly Displayed Plate')
# Ticket(summons_number=8214550531, plate_id='HJY2207', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 9), violation_code=74, vehicle_body_type='4DSD', vehicle_make='HYUND', violation_description='74-Missing Display Plate')
# Ticket(summons_number=8487469012, plate_id='27527ME', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 27), violation_code=74, vehicle_body_type='DELV', vehicle_make='INTER', violation_description='74-Missing Display Plate')
# Ticket(summons_number=8034780236, plate_id='HCD3158', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 2), violation_code=74, vehicle_body_type='SUBN', vehicle_make='KIA', violation_description='74A-Improperly Displayed Plate')
# Ticket(summons_number=8545052455, plate_id='HMK1149', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 7), violation_code=74, vehicle_body_type='4DSD', vehicle_make='ME/BE', violation_description='74-Missing Display Plate')
# Ticket(summons_number=1411263467, plate_id='BLANKPLATE', registration_state=99, plate_type=999, issue_date=datetime.date(2017, 2, 13), violation_code=74, vehicle_body_type='SDN', vehicle_make='NISSA', violation_description='')
# Ticket(summons_number=8540001550, plate_id='HLA4803', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 3, 23), violation_code=74, vehicle_body_type='4DSD', vehicle_make='SAAB', violation_description='74-Missing Display Plate')
# Ticket(summons_number=8556155431, plate_id='HFB9919', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 26), violation_code=75, vehicle_body_type='4DSD', vehicle_make='DODGE', violation_description='75-No Match-Plate/Reg. Sticker')
# Ticket(summons_number=8394016790, plate_id='31690BB', registration_state='NY', plate_type='OMR', issue_date=datetime.date(2016, 9, 6), violation_code=77, vehicle_body_type='BUS', vehicle_make='AM/T', violation_description='77-Parked Bus (exc desig area)')
# Ticket(summons_number=1419472306, plate_id='56090BA', registration_state='NY', plate_type='OMR', issue_date=datetime.date(2017, 2, 20), violation_code=77, vehicle_body_type='BUS', vehicle_make='INTER', violation_description='')
# Ticket(summons_number=8363508688, plate_id=97256, registration_state='MA', plate_type='APP', issue_date=datetime.date(2016, 8, 13), violation_code=77, vehicle_body_type='BUS', vehicle_make='NS/OT', violation_description='77-Parked Bus (exc desig area)')
# Ticket(summons_number=1407740258, plate_id='2513JMG', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 11), violation_code=78, vehicle_body_type='DELV', vehicle_make='FRUEH', violation_description='')
# Ticket(summons_number=8081047670, plate_id='AG84195', registration_state='AZ', plate_type='PAS', issue_date=datetime.date(2016, 9, 1), violation_code=78, vehicle_body_type='DELV', vehicle_make='GMC', violation_description='78-Nighttime PKG on Res Street')
# Ticket(summons_number=8357010039, plate_id='ZBK5659', registration_state='PA', plate_type='PAS', issue_date=datetime.date(2016, 9, 16), violation_code=78, vehicle_body_type='FLAT', vehicle_make='NS/OT', violation_description='78-Nighttime PKG on Res Street')
# Ticket(summons_number=1408164401, plate_id='GCP8663', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 9, 30), violation_code=80, vehicle_body_type='SUBN', vehicle_make='CHEVR', violation_description='')
# Ticket(summons_number=7065087220, plate_id='35989MJ', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 8, 28), violation_code=82, vehicle_body_type='VAN', vehicle_make='CHEVR', violation_description='82-Unaltered Commerc Vehicle')
# Ticket(summons_number=8472028628, plate_id='80921MH', registration_state='NY', plate_type='COM', issue_date=datetime.date(2017, 1, 30), violation_code=82, vehicle_body_type='VAN', vehicle_make='CHEVR', violation_description='82-Unaltered Commerc Vehicle')
# Ticket(summons_number=8413507250, plate_id='XCGT11', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 10, 18), violation_code=82, vehicle_body_type='PICK', vehicle_make='CHEVR', violation_description='82-Unaltered Commerc Vehicle')
# Ticket(summons_number=8498413898, plate_id=2028133, registration_state='IN', plate_type='PAS', issue_date=datetime.date(2017, 5, 24), violation_code=84, vehicle_body_type='DELV', vehicle_make='FRUEH', violation_description='84-Platform lifts in low posit')
# Ticket(summons_number=8484405837, plate_id=2028134, registration_state='IN', plate_type='PAS', issue_date=datetime.date(2017, 2, 15), violation_code=84, vehicle_body_type='DELV', vehicle_make='FRUEH', violation_description='84-Platform lifts in low posit')
# Ticket(summons_number=8040125108, plate_id='AT985A', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 8, 29), violation_code=84, vehicle_body_type='DELV', vehicle_make='FRUEH', violation_description='84-Platform lifts in low posit')
# Ticket(summons_number=8521821979, plate_id='XJX4470', registration_state='PA', plate_type='PAS', issue_date=datetime.date(2017, 5, 18), violation_code=84, vehicle_body_type='TR/C', vehicle_make='FRUEH', violation_description='84-Platform lifts in low posit')
# Ticket(summons_number=7662741072, plate_id='XY237D', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 8, 9), violation_code=84, vehicle_body_type='DELV', vehicle_make='HINO', violation_description='84-Platform lifts in low posit')
# Ticket(summons_number=8529157072, plate_id=2380604, registration_state='IN', plate_type='PAS', issue_date=datetime.date(2017, 3, 29), violation_code=84, vehicle_body_type='DELV', vehicle_make='INTER', violation_description='84-Platform lifts in low posit')
# Ticket(summons_number=8354508808, plate_id='21239MG', registration_state='NY', plate_type='COM', issue_date=datetime.date(2016, 9, 9), violation_code=84, vehicle_body_type='DELV', vehicle_make='MI/F', violation_description='84-Platform lifts in low posit')
# Ticket(summons_number=1414702700, plate_id='AT785J', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2016, 11, 27), violation_code=85, vehicle_body_type='TRAC', vehicle_make='FRUEH', violation_description='')
# Ticket(summons_number=8466533837, plate_id='XANK50', registration_state='NJ', plate_type='PAS', issue_date=datetime.date(2017, 4, 29), violation_code=85, vehicle_body_type='DELV', vehicle_make='HIN', violation_description='85-Storage-3 hour Commercial')
# Ticket(summons_number=8525168063, plate_id='HBN8474', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 5, 30), violation_code=91, vehicle_body_type='SUBN', vehicle_make='HONDA', violation_description='91-Veh for Sale (Dealer Only)')
# Ticket(summons_number=1420730010, plate_id='GFW3620', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 6, 10), violation_code=98, vehicle_body_type='SUBN', vehicle_make='CHEVR', violation_description='')
# Ticket(summons_number=1414049870, plate_id='EJS4309', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2016, 8, 5), violation_code=98, vehicle_body_type='SDN', vehicle_make='NISSA', violation_description='')
# Ticket(summons_number=1420795430, plate_id='HBS5720', registration_state='NY', plate_type='PAS', issue_date=datetime.date(2017, 4, 18), violation_code=98, vehicle_body_type='SDN', vehicle_make='NISSA', violation_description='')
